# %% [markdown]
# <!-- TODO: Use bhav_copy_equities with differenet date to get historical data -->

# %%
import pandas as pd
from datetime import date
import nselib
from nselib import capital_market
#  import nsepy as nse

# %%
holiday_df = nselib.trading_holiday_calendar()
print(holiday_df)
# Out:
#                                    Product  tradingDate    weekDay  \
# 0                          Corporate Bonds  22-Jan-2024     Monday
# 1                          Corporate Bonds  26-Jan-2024     Friday
# 2                          Corporate Bonds  19-Feb-2024     Monday
# 3                          Corporate Bonds  08-Mar-2024     Friday
# 4                          Corporate Bonds  25-Mar-2024     Monday
# ..                                     ...          ...        ...
# 15  Securities Lending & Borrowing Schemes  12-Oct-2024   Saturday
# 16  Securities Lending & Borrowing Schemes  01-Nov-2024     Friday
# 17  Securities Lending & Borrowing Schemes  02-Nov-2024   Saturday
# 18  Securities Lending & Borrowing Schemes  15-Nov-2024     Friday
# 19  Securities Lending & Borrowing Schemes  25-Dec-2024  Wednesday
#
#                              description Sr_no
# 0                      Special Holiday\r     1
# 1                         Republic Day\r     2
# ...

# %%
bce_df = capital_market.bhav_copy_equities(trade_date='02-01-2023')
print(bce_df)
# Out:
#           SYMBOL SERIES     OPEN     HIGH      LOW   CLOSE     LAST  \
# 0     1018GS2026     GS   118.00   118.00   118.00   118.0   118.00
# 1     182D020223     TB    99.00    99.00    99.00    99.0    99.00
# 2     182D180523     TB    96.80    96.80    96.80    96.8    96.80
# 3      20MICRONS     EQ    91.05    93.20    91.05    92.9    93.00
# 4     21STCENMGM     EQ    22.95    22.95    22.10    22.3    22.25
# ...          ...    ...      ...      ...      ...     ...      ...
# 2378        ZOTA     EQ   308.20   327.85   305.95   324.4   324.55
# 2379       ZUARI     EQ   164.75   165.75   161.70   162.5   163.00
# 2380    ZUARIIND     EQ   150.80   151.00   147.50   148.1   149.75
# 2381   ZYDUSLIFE     EQ   419.85   421.45   414.15   420.1   420.30
# 2382   ZYDUSWELL     EQ  1510.00  1538.90  1509.95  1530.1  1535.00
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES
# 0        116.00        648  7.646400e+04  02-JAN-2023            4
# ...

# %%
print(bce_df.columns)
# Out:
# Index(['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST', 'PREVCLOSE',
#        'TOTTRDQTY', 'TOTTRDVAL', 'TIMESTAMP', 'TOTALTRADES'],
#       dtype='object')

# %%
print(bce_df.shape[0])
# Out:
# 2383

# %%
print(bce_df[bce_df['TIMESTAMP']=='29-12-2022'])
# Out:
# Empty DataFrame
# Columns: [SYMBOL, SERIES, OPEN, HIGH, LOW, CLOSE, LAST, PREVCLOSE, TOTTRDQTY, TOTTRDVAL, TIMESTAMP, TOTALTRADES]
# Index: []

# %%
bcwd = capital_market.bhav_copy_with_delivery(trade_date='01-01-2023') 
print(bcwd)
# Out:
#           SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0     1018GS2026     GS      116.00      116.00     116.00       116.00
# 1      20MICRONS     EQ       91.45       92.55      90.20        91.05
# 2     21STCENMGM     EQ       22.00       22.55      22.00        22.55
# 3      3IINFOLTD     EQ       41.00       41.60      40.65        40.75
# 4        3MINDIA     EQ    22075.05    22188.95   21900.00     21943.10
# ...          ...    ...         ...         ...        ...          ...
# 2316        ZOTA     EQ      300.00      312.00     300.00       303.65
# 2317       ZUARI     EQ      166.75      170.80     162.30       163.90
# 2318    ZUARIIND     EQ      148.85      152.50     147.00       148.65
# 2319   ZYDUSLIFE     EQ      419.45      421.85     413.55       419.95
# 2320   ZYDUSWELL     EQ     1506.00     1525.00    1492.00      1506.80
#
#       PREV_CLOSE  TTL_TRD_QNTY  TURNOVER_LACS  NO_OF_TRADES DELIV_QTY  \
# ...

# %%
print(bcwd.columns)
# Out:
# Index(['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST', 'PREVCLOSE',
#        'TOTTRDQTY', 'TOTTRDVAL', 'TIMESTAMP', 'TOTALTRADES'],
#       dtype='object')
# Index(['SYMBOL', 'SERIES', 'OPEN_PRICE', 'HIGH_PRICE', 'LOW_PRICE',
#        'CLOSE_PRICE', 'PREV_CLOSE', 'TTL_TRD_QNTY', 'TURNOVER_LACS',
#        'NO_OF_TRADES', 'DELIV_QTY', 'DELIV_PER', 'DATE1'],
#       dtype='object')

# %%
capital_market.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1961        ZOTA                  Zota Health Care LImited      EQ
# 1962       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1963    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1964   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1965   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# ...

# %%
capital_market.nifty50_equity_list()
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8            Bharat Petroleum Corporation Ltd.
# 9                           Bharti Airtel Ltd.
# 10                   Britannia Industries Ltd.
# 11                                  Cipla Ltd.
# 12                             Coal India Ltd.
# 13                    Divi's Laboratories Ltd.
# 14               Dr. Reddy's Laboratories Ltd.
# 15                          Eicher Motors Ltd.
# 16                      Grasim Industries Ltd.
# 17                       HCL Technologies Ltd.
# 18                              HDFC Bank Ltd.
# ...

# %%
print(list(bci_df['Index Name']))
# Out:
# ['Nifty 50', 'Nifty Next 50', 'Nifty 100', 'Nifty 200', 'Nifty 500', 'Nifty Midcap 50', 'NIFTY Midcap 100', 'NIFTY Smallcap 100', 'Nifty50 Dividend Points', 'Nifty Auto', 'Nifty Bank', 'Nifty Energy', 'Nifty Financial Services', 'Nifty FMCG', 'Nifty IT', 'Nifty Media', 'Nifty Metal', 'Nifty MNC', 'Nifty Pharma', 'Nifty PSU Bank', 'Nifty Realty', 'Nifty India Consumption', 'Nifty Commodities', 'Nifty Dividend Opportunities 50', 'Nifty Infrastructure', 'Nifty PSE', 'Nifty Services Sector', 'Nifty50 Shariah', 'Nifty500 Shariah', 'Nifty Low Volatility 50', 'Nifty Alpha 50', 'Nifty High Beta 50', 'Nifty100 Equal Weight', 'Nifty100 Liquid 15', 'Nifty CPSE', 'Nifty50 Value 20', 'Nifty Midcap Liquid 15', 'Nifty Shariah 25', 'India VIX', 'Nifty Growth Sectors 15', 'Nifty50 TR 1x Inverse', 'Nifty50 TR 2x Leverage', 'Nifty50 PR 1x Inverse', 'Nifty50 PR 2x Leverage', 'NIFTY100 Quality 30', 'Nifty 50 Futures Index', 'NIFTY50 Equal Weight', 'Nifty 50 Futures TR Index', 'Nifty Mahindra Group', 'Nif
# ...

# %%
bci_df = capital_market.capital_market_data.bhav_copy_indices('15-03-2024')
print(bci_df)
# Out:
#                                     Index Name  Index Date Open Index Value  \
# 0                                     Nifty 50  15-03-2024         22064.85
# 1                                Nifty Next 50  15-03-2024         58414.35
# 2                                    Nifty 100  15-03-2024         22548.55
# 3                                    Nifty 200  15-03-2024          12113.8
# 4                                    Nifty 500  15-03-2024         19867.75
# ..                                         ...         ...              ...
# 106                Nifty Composite G-sec Index  15-03-2024          2670.16
# 107                Nifty 10 yr Benchmark G-Sec  15-03-2024          2286.47
# 108  Nifty 10 yr Benchmark G-Sec (Clean Price)  15-03-2024           878.31
# 109                        Nifty 1D Rate Index  15-03-2024                -
# 110                                Nifty50 USD  15-03-2024                -
#
# ...

# %%
print(bci_df.columns)
# Out:
# Index(['Index Name', 'Index Date', 'Open Index Value', 'High Index Value',
#        'Low Index Value', 'Closing Index Value', 'Points Change', 'Change(%)',
#        'Volume', 'Turnover (Rs. Cr.)', 'P/E', 'P/B', 'Div Yield'],
#       dtype='object')

# %%
print(bci_df.shape)
# Out:
# (111, 13)

# %%
print(bci_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index Name           111 non-null    object
#  1   Index Date           111 non-null    object
#  2   Open Index Value     111 non-null    object
#  3   High Index Value     111 non-null    object
#  4   Low Index Value      111 non-null    object
#  5   Closing Index Value  111 non-null    float64
#  6   Points Change        111 non-null    float64
#  7   Change(%)            111 non-null    object
#  8   Volume               111 non-null    object
#  9   Turnover (Rs. Cr.)   111 non-null    object
#  10  P/E                  111 non-null    object
#  11  P/B                  111 non-null    object
#  12  Div Yield            111 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 11.4+ KB
# None

# %%
capital_market.capital_market_data.validate_date_param

# %%
capital_market.market_watch_all_indices()
# Out:
#                      key                                      index  \
# 0   BROAD MARKET INDICES                                   NIFTY 50
# 1   BROAD MARKET INDICES                              NIFTY NEXT 50
# 2   BROAD MARKET INDICES                                  NIFTY 100
# 3   BROAD MARKET INDICES                                  NIFTY 200
# 4   BROAD MARKET INDICES                                  NIFTY 500
# ..                   ...                                        ...
# 68  FIXED INCOME INDICES  NIFTY 10 YR BENCHMARK G-SEC (CLEAN PRICE)
# 69  FIXED INCOME INDICES                   NIFTY 4-8 YR G-SEC INDEX
# 70  FIXED INCOME INDICES                 NIFTY 11-15 YR G-SEC INDEX
# 71  FIXED INCOME INDICES          NIFTY 15 YR AND ABOVE G-SEC INDEX
# 72  FIXED INCOME INDICES                NIFTY COMPOSITE G-SEC INDEX
#
#           indexSymbol      last  variation  percentChange      open      high  \
# ...

# %%
capital_market.index_data('NIFTY 50','17-03-2022','17-03-2024')
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/nselib/capital_market/capital_market_data.py:226: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/nselib/capital_market/capital_market_data.py:235, in get_index_data(index, from_date, to_date)
#     234 data_json = nse_urlfetch(url).json()
# --> 235 data_close_df = pd.DataFrame(data_json['data']['indexCloseOnlineRecords']).drop(columns=['_id', "EOD_TIMESTAMP"])
# ...

# %%
print(bce.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2383 entries, 0 to 2382
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SYMBOL       2383 non-null   object
#  1   SERIES       2376 non-null   object
#  2   OPEN         2383 non-null   float64
#  3   HIGH         2383 non-null   float64
#  4   LOW          2383 non-null   float64
#  5   CLOSE        2383 non-null   float64
#  6   LAST         2383 non-null   float64
#  7   PREVCLOSE    2383 non-null   float64
#  8   TOTTRDQTY    2383 non-null   int64
#  9   TOTTRDVAL    2383 non-null   float64
#  10  TIMESTAMP    2383 non-null   object
#  11  TOTALTRADES  2383 non-null   int64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 223.5+ KB
# None

# %% [markdown]
# Symbol: The stock symbol/name or the identifier of the security.
#
# Series: The series of the security, such as equity shares, debentures, etc. Values are EQ, BE, BL, BT, GC, IL and IQ.
#
# Open: Price at which the security opened on the day of the report.
#
# High: Highest traded price of the security during the day.
#
# Low: Lowest traded price of the security during the day.
#
# Close: Price at which the security was traded at the end of the market.
#
# Last: Price at which the security was traded at the last transaction before the close of the market.
#
# Prev Close: Closing price of the security on the previous trading day.
#
# TOTTRDQTY: The total quantity or number of shares traded during the day.
#
# TOTTRDVAL: The total value of the shares traded, calculated as the product of the traded quantity and the last traded price.
#
# TIMESTAMP: The date of the report.
#
# TOTALTRADES: The number of trades that were executed for the security during the day. E.g. for a stock, Trade 1 has quantity = 100, Trade 2 quantity = 1000. TOTALTRADES = 2 and TOTTRDQTY = 1100
#
# ISIN: International Securities Identification Number. Identify the security across exchanges using this ID.

# %%
capital_market.equity_list()

# %%
symbols = list(capital_market.equity_list()['SYMBOL'])
print(symbols)
print(len(symbols))

# %%
capital_market.price_volume_and_deliverable_position_data(symbol='ASIANPAINT',period='1W')

# %%
# # 41 mins
# [10137 rows x 15 columns]
data = pd.DataFrame()
for symbol in symbols:
    df =  capital_market.price_volume_and_deliverable_position_data(symbol=symbol,period='1Y')
    data = pd.concat([data, df], ignore_index=True)
print(data)

# %%
# get_price_volume_data
capital_market.price_volume_data(symbol='SBIN',from_date='17-03-2022',to_date='17-06-2023')
# capital_market.price_volume_and_deliverable_position_data(symbol='ASIANPAINT',period='1W')

# %%
# 41 mins
data = pd.DataFrame()
for symbol in symbols:
    df =  capital_market.price_volume_and_deliverable_position_data(symbol=symbol,period='1w')
    data = pd.concat([data, df], ignore_index=True)
print(data)

# %%
import calendar
def date_iter(year, month):
    for i in range(1, calendar.monthlen(year, month) + 1):
        yield date(year, month, i)

for d in date_iter(2019, 12):
    print(d)

# %%
import datetime, calendar
year = 2014
month = 1
num_days = calendar.monthrange(year, month)[1]
print(num_days)
days = [datetime.date(year, month, day) for day in range(1, num_days+1)]
print(days)

# %%
print(pd.to_datetime(holiday_df['tradingDate']).dt.strftime("%d-%m-%Y"))

# %%
import pandas as pd
from datetime import date, timedelta
import nselib
from nselib import capital_market
from collections import namedtuple
from calendar import monthrange
from time import time

year = 2023
months = [x for x in range(1, 13)]
# sdate = '01-01-2023'
# edate = '31-12-2023'
for month in months:

    num_days = monthrange(year, month)[1]
    print(num_days)
    sdate = date(2023, month, 1)  # start date
    edate = date(2023, month, num_days)  # end date
    dates = pd.date_range(sdate, edate, freq="d").strftime("%d-%m-%Y").tolist()
    print(dates)
    bhav_df = pd.DataFrame()

    for date in dates:
        try:
            t_start = time()
            # print(f'Calling bhav_copy_with_delivery with trade_date = {date}')
            temp_df = capital_market.bhav_copy_with_delivery(trade_date=date)
            bhav_df = pd.concat([bhav_df, temp_df], ignore_index=True)
            t_end = time()
            print(f"Took %.3f second for {date}" % (t_end - t_start))
        except KeyError:
            pass
    print(f"Print complete for {month}")
    print(bhav_df.shape)
print(f"Print complete for {year}")

# %%
import pandas as pd
from datetime import date, timedelta
import nselib
from nselib import capital_market
from collections import namedtuple
from calendar import monthrange
from time import time


def get_dates(year, month=None):
    dates = {}
    months = [x for x in range(1, 13)]
    for month in months:
        # month_start = time()
        num_days = monthrange(year, month)[1]
        sdate = date(year=year, month=month, day=1)  # start date
        edate = date(year=year, month=month, day=num_days)  # end date
        dates[month] = (
            pd.date_range(sdate, edate, freq="d").strftime("%d-%m-%Y").tolist()
        )
        # bhav_df = pd.DataFrame()
    return dates

# %%
import pandas as pd
from datetime import date
from nselib import capital_market
from calendar import monthrange
import argparse
import os
from tqdm import tqdm

year = 2023

def yearly_bhav_data(year, month, dates):
    """
    Takes year, month and dates as arguments and downloads
    bhav_copy_with_delivery data from nselib for the given dates
    and saves it in a csv file for each date.

    Args:
        year : integer
        month : integer
        dates : list of dates with each date in the format '%d-%m-%Y'

    """
    # print(f"Downloading data for {month:02}-{year}")
    # MONTH_DIR = f"{BASE_DIR}/{month:02}"
    # if not os.path.exists(MONTH_DIR):
    #     os.makedirs(MONTH_DIR)
    for trade_date in tqdm(dates):
        try:
            count1=0
            count2=0
            temp_df = capital_market.bhav_copy_equities(trade_date=trade_date)
            count1 = temp_df[temp_df['TIMESTAMP']=='29-12-2022'].shape[0]
            count2 = temp_df[temp_df['TIMESTAMP']=='30-12-2022'].shape[0]
            if(count1>0 or count2>0):
                print(f"{count1} ,{count2} , {trade_date}")
            # temp_df.to_csv(f"{MONTH_DIR}/bhavdata_{trade_date}.csv", index=False)
        except KeyError:
            # print(f"No activity on {trade_date}")
            pass
        # print(f"Completed downloading data for {month:02}-{year}")

months = [x for x in range(1, 13)]

for month in months:
    num_days = monthrange(year, month)[1]
    sdate = date(year=year, month=month, day=1)  # start date
    edate = date(year=year, month=month, day=num_days)  # end date
    dates = pd.date_range(sdate, edate, freq="d").strftime("%d-%m-%Y").tolist()
    yearly_bhav_data(year, month, dates)


symbols = list(capital_market.equity_list()["SYMBOL"])
print(bce_df[bce_df['TIMESTAMP']=='29-12-2022'])
# Out:
# ...
# 100%|██████████| 31/31 [00:20<00:00,  1.49it/s]
# Empty DataFrame
# Columns: [SYMBOL, SERIES, OPEN, HIGH, LOW, CLOSE, LAST, PREVCLOSE, TOTTRDQTY, TOTTRDVAL, TIMESTAMP, TOTALTRADES]
# Index: []
